# %%
import os

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !mv ~/Downloads/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !cd task_2
# !mkdir -p data
# !kaggle datasets download -d alessiocorrado99/animals10 -p data/ --unzip

# %%
classes = os.listdir(os.path.join(path, 'raw-img'))
print("Classes in the dataset:")
for cls in classes:
    print(f"- {cls}")

# %%
for item in os.listdir("../data/raw-img"):
    print(item)

# %%
mapping = {
    "cane": "dog",
    "gatto": "cat", 
    "mucca": "cow",
    "elefante": "elephant",
    "farfalla": "butterfly",
    "gallina": "chicken",
    "cavallo": "horse",
    "pecora": "sheep",
    "ragno": "spider",
    "scoiattolo": "squirrel",
}

base = "../data/raw-img"

for italian, english in mapping.items():
    src = os.path.join(base, italian)
    dst = os.path.join(base, english)
    if os.path.exists(src):
        os.rename(src, dst)
        print(f"{italian} → {english}")
    else:
        print(f"not found: {src}")
